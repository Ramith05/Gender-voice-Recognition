# %% [markdown]
# ## Project 01 GENDER VOICE RECOGNITION

# %%
import numpy as np
import pandas as pd
import os
print(os.listdir())
# Out:
# [' Normal Distribution and CLT & CI.ipynb', '(1) Python and Sequence Data type.ipynb', '(2) Dictionaries.ipynb', '(3) Series_Data type.ipynb', '.ipynb_checkpoints', 'ALL MY PYTHON', 'Data science Assignment 3.ipynb', 'Gender Voice Recognition Model Building.ipynb', 'Gender Voice Recognition Project.ipynb', 'New Python Skills', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
import warnings
warnings.filterwarnings('ignore')
# read file
voice=pd.read_csv("C:\\Users\\gsram\\Desktop\\assignbook\\voice1.csv")
voice.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402905  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
voice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
#  19  modindx   3168 non-null   float64
#  20  label     3168 non-null   object
# dtypes: float64(20), object(1)
# memory usage: 519.9+ KB

# %%
voice.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# min       0.014558     0.141735     2.068455     0.738651     0.036876
# 25%       0.042560     1.649569     5.669547     0.861811     0.258041
# 50%       0.094280     2.197101     8.318463     0.901767     0.396335
# 75%       0.114175     2.931694    13.648905     0.928713     0.533676
# max       0.252225    34.725453  1309.612887     0.981997     0.842936
#
#               mode     centroid      meanfun       minfun       maxfun  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.165282     0.180907     0.142807     0.036802     0.258842
# std       0.077203     0.029918     0.032304     0.019220     0.030077
# min       0.000000     0.039363     0.055565     0.009775     0.103093
# 25%       0.118016     0.163662     0.116998     0.018223     0.253968
# 50%       0.186599     0.184838     0.140519     0.046110     0.271186
# 75%       0.221104     0.199146     0.169581     0.047904     0.277457
# max       0.280000     0.251124     0.237636     0.204082     0.279114
#
#            meandom       mindom       maxdom      dfrange      modindx
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.829211     0.052647     5.047277     4.994630     0.173752
# std       0.525205     0.063299     3.521157     3.520039     0.119454
# min       0.007812     0.004883     0.007812     0.000000     0.000000
# 25%       0.419828     0.007812     2.070312     2.044922     0.099766
# 50%       0.765795     0.023438     4.992188     4.945312     0.139357
# 75%       1.177166     0.070312     7.007812     6.992188     0.209183
# max       2.957682     0.458984    21.867188    21.843750     0.932374

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
voice["label"] = le.fit_transform(voice["label"])
le.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
voice[:]=preprocessing.MinMaxScaler().fit_transform(voice)
voice
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0     0.096419  0.473409  0.084125  0.060063  0.204956  0.254828  0.367853
# 1     0.125828  0.505075  0.116900  0.077635  0.215683  0.246961  0.644279
# 2     0.179222  0.675536  0.102873  0.034284  0.385912  0.457148  0.885255
# 3     0.528261  0.554611  0.587559  0.389906  0.715802  0.407358  0.031549
# 4     0.452195  0.627209  0.454272  0.317627  0.707515  0.474474  0.027742
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.436911  0.684871  0.570361  0.198513  0.686256  0.577704  0.046854
# 3164  0.362946  0.731172  0.262871  0.171937  0.702595  0.621185  0.015961
# 3165  0.484949  0.799042  0.690337  0.134329  0.786967  0.742124  0.050161
# 3166  0.492516  0.745692  0.695311  0.175136  0.767804  0.681107  0.041908
# 3167  0.595700  0.768964  0.687590  0.282629  0.901780  0.699289  0.045203
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0     0.208279  0.635798  0.564526  ...  0.096419  0.157706  0.030501
# 1     0.483766  0.630964  0.591578  ...  0.125828  0.287642  0.031140
# 2     0.782275  0.442738  0.548382  ...  0.179222  0.236945  0.030264
# 3     0.001613  0.923261  0.856457  ...  0.528261  0.183442  0.041287
# 4     0.001732  0.958736  0.926348  ...  0.452195  0.279190  0.036829
# ...        ...       ...       ...  ...       ...       ...       ...
# 3163  0.003489  0.921665  0.901057  ...  0.436911  0.698762  0.380813
# 3164  0.000333  0.912549  0.834545  ...  0.362946  0.732760  0.126776
# 3165  0.003469  0.855587  0.765849  ...  0.484949  0.847759  0.153011
# 3166  0.002539  0.870307  0.792241  ...  0.492516  0.641561  0.127158
# 3167  0.002830  0.822610  0.700510  ...  0.595700  0.714235  0.270097
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0     0.981526  0.000000  0.006452  0.000000  0.000000  0.000000    1.0
# 1     0.834600  0.000407  0.006452  0.002144  0.002146  0.056449    1.0
# 2     0.954963  0.000060  0.006452  0.000357  0.000358  0.049885    1.0
# 3     0.834600  0.065659  0.006452  0.025375  0.025393  0.265043    1.0
# 4     0.929285  0.238994  0.006452  0.250536  0.250715  0.223380    1.0
# ...        ...       ...       ...       ...       ...       ...    ...
# 3163  0.904450  0.279703  0.006452  0.192280  0.192418  0.173674    0.0
# 3164  0.981526  0.305791  0.075269  0.167977  0.166667  0.298053    0.0
# 3165  0.981526  0.164908  0.006452  0.134024  0.134120  0.208885    0.0
# 3166  0.834600  0.265621  0.006452  0.164046  0.164163  0.333559    0.0
# 3167  0.954963  0.074312  0.006452  0.025018  0.025036  0.375386    0.0
#
# [3168 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.subplots(4,5,figsize=(30,30))
for i in range(1,21):
    plt.subplot(4,5,i)
    plt.title(voice.columns[i-1])
    sns.kdeplot(voice.loc[voice['label'] == 0, voice.columns[i-1]], color= 'green', label='F')
    sns.kdeplot(voice.loc[voice['label'] == 1, voice.columns[i-1]], color= 'blue', label='M')

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn import ensemble
from sklearn import neighbors
from sklearn import svm

# %%
train, test = train_test_split(voice, test_size=0.2)

# %%
train.head()
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 2033  0.692969  0.309377  0.702067  0.695188  0.707308  0.081699  0.075315
# 661   0.416114  0.503122  0.401565  0.378700  0.617814  0.323967  0.083344
# 2289  0.812418  0.270826  0.791003  0.774785  0.862486  0.149449  0.049145
# 2840  0.915836  0.138600  0.891198  0.906597  0.894010  0.042973  0.077707
# 835   0.637091  0.407112  0.720224  0.468698  0.761431  0.369690  0.051784
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 2033  0.007020  0.618439  0.445486  ...  0.692969  0.476613  0.035916
# 661   0.009446  0.786454  0.697214  ...  0.416114  0.088833  0.031626
# 2289  0.003163  0.502472  0.276227  ...  0.812418  0.622825  0.198968
# 2840  0.007285  0.207493  0.123060  ...  0.915836  0.809063  0.216466
# 835   0.004616  0.737065  0.410899  ...  0.637091  0.337816  0.195986
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 2033  0.791561  0.457812  0.384946  0.293781  0.286123  0.120262    0.0
# 661   0.904450  0.048787  0.023656  0.030736  0.030401  0.292942    1.0
# 2289  0.999749  0.413765  0.040860  0.443531  0.443133  0.067029    0.0
# 2840  0.990585  0.851677  0.505376  0.515368  0.505365  0.134972    0.0
# 835   0.999749  0.266755  0.040860  0.244103  0.243562  0.084769    1.0
#
# [5 rows x 21 columns]

# %%
x_train = train.iloc[:, :-1]
y_train = train["label"]
x_test = test.iloc[:, :-1]
y_test = test["label"]

# %%
x_train3 = train[["meanfun","IQR","Q25"]]
y_train3 = train["label"]
x_test3 = test[["meanfun","IQR","Q25"]]
y_test3 = test["label"]

# %%
def classify(model,x_train,y_train,x_test,y_test):
    from sklearn.metrics import classification_report
    target_names = ['female', 'male']
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print(classification_report(y_test, y_pred, target_names=target_names, digits=4))
    a = metrics.accuracy_score(y_test, y_pred)
    print("Accuracy:",a)
    return a

# %%
accli=pd.read_csv("C:\\Users\\gsram\\Desktop\\assignbook\\Book4.csv")
accli.set_index("Algorithm", inplace = True)
accli.at['K-Nearest Neighbours', 'Accuracy (considering only IQR, meanfun & Q25)'] = 0
accli.at['K-Nearest Neighbours', 'Accuracy (considering all attributes)'] = 0
accli.at['Decision Tree', 'Accuracy (considering only IQR, meanfun & Q25)'] = 0
accli.at['Decision Tree', 'Accuracy (considering all attributes)'] = 0
accli.at['Random Forest', 'Accuracy (considering only IQR, meanfun & Q25)'] = 0
accli.at['Random Forest', 'Accuracy (considering all attributes)'] = 0
accli.at['Support Vector Machine', 'Accuracy (considering only IQR, meanfun & Q25)'] = 0
accli.at['Support Vector Machine', 'Accuracy (considering all attributes)'] = 0

# %%
accli
# Out:
#                                  Accuracy (considering only IQR, meanfun & Q25)  \
# Algorithm
# K-Nearest Neighbours                                                   0.000000
# Naïve Bayes                                                            0.963197
# Decision Tree                                                          0.000000
# Random Forest                                                          0.000000
# XgBoost                                                                0.972660
# Support Vector Machine                                                 0.000000
# Neural Network (MLP Classifier)                                        0.973712
#
#                                  Accuracy (considering all attributes)
# Algorithm
# K-Nearest Neighbours                                          0.000000
# Naïve Bayes                                                   0.900105
# Decision Tree                                                 0.000000
# Random Forest                                                 0.000000
# XgBoost                                                       0.985279
# Support Vector Machine                                        0.000000
# Neural Network (MLP Classifier)                               0.980021

# %%
list = accli.index
list
# Out:
# Index(['K-Nearest Neighbours', 'Naïve Bayes', 'Decision Tree', 'Random Forest',
#        'XgBoost', 'Support Vector Machine', 'Neural Network (MLP Classifier)'],
#       dtype='object', name='Algorithm')

# %% [markdown]
# ## Decision Tree

# %%
def dt_error(n,x_train,y_train,x_test,y_test):
    nodes = range(2, n)
    error_rate = []
    for k in nodes:
        model = tree.DecisionTreeClassifier(max_leaf_nodes=k)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    kloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at n=%s." % (error_rate[kloc], nodes[kloc]))
    plt.plot(nodes, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.xlabel('Tree Size')
    plt.ylabel('Cross-Validated MSE')
    plt.show()
    return nodes[kloc]

# %%
n=dt_error(10,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.026813880126182965 occurs at n=8.

# %%
def rf_error(n,x_train,y_train,x_test,y_test):
    error_rate = []
    e=range(1,n,20)
    for i in e:
        model = ensemble.RandomForestClassifier(n_estimators = i)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    nloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at n=%s." % (error_rate[nloc], e[nloc]))

    plt.plot(e, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. n Value')
    plt.xlabel('n')
    plt.ylabel('Error Rate')
    plt.show()
    return e[nloc]

# %%
e=rf_error(100,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.017350157728706624 occurs at n=81.

# %%
model=ensemble.RandomForestClassifier(n_estimators = e)
t = classify(model,x_train,y_train,x_test,y_test)
accli.at['Random Forest', 'Accuracy (considering all attributes)'] = t
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9775    0.9838    0.9806       309
#         male     0.9845    0.9785    0.9815       325
#
#     accuracy                         0.9811       634
#    macro avg     0.9810    0.9811    0.9811       634
# weighted avg     0.9811    0.9811    0.9811       634
#
# Accuracy: 0.9810725552050473

# %% [markdown]
# ## KNearest Neighbours

# %%
def knn_error(k,x_train,y_train,x_test,y_test):
    error_rate = []
    K=range(1,k)
    for i in K:
        knn = neighbors.KNeighborsClassifier(n_neighbors = i)
        knn.fit(x_train, y_train)
        y_pred = knn.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    kloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at k=%s." % (error_rate[kloc], K[kloc]))

    plt.plot(K, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. K Value')
    plt.xlabel('K')
    plt.ylabel('Error Rate')
    plt.show()
    return K[kloc]

# %%
k=knn_error(21,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.014195583596214511 occurs at k=10.

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = k)
t = classify(model,x_train,y_train,x_test,y_test)
accli.at['K-Nearest Neighbours', 'Accuracy (considering all attributes)'] = t
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9839    0.9871    0.9855       309
#         male     0.9877    0.9846    0.9861       325
#
#     accuracy                         0.9858       634
#    macro avg     0.9858    0.9858    0.9858       634
# weighted avg     0.9858    0.9858    0.9858       634
#
# Accuracy: 0.9858044164037855

# %%
k=knn_error(21,x_train3,y_train3,x_test3,y_test3)
# Out:
# Lowest error is 0.025236593059936908 occurs at k=5.

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = k)
t = classify(model,x_train3,y_train3,x_test3,y_test3)
accli.at['K-Nearest Neighbours', 'Accuracy (considering only IQR, meanfun & Q25)'] = t
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9835    0.9644    0.9739       309
#         male     0.9668    0.9846    0.9756       325
#
#     accuracy                         0.9748       634
#    macro avg     0.9751    0.9745    0.9747       634
# weighted avg     0.9749    0.9748    0.9748       634
#
# Accuracy: 0.9747634069400631

# %% [markdown]
# ## Support Vector Machine

# %%
def svm_kernel(x_train,y_train,x_test,y_test):
    rate=[]
    kernel=['rbf','poly','linear']
    for i in kernel:
        model=svm.SVC(kernel=i).fit(x_train,y_train)
        y_pred=model.predict(x_train)
        print(i, ' in-sample accuracy in SVM: ', accuracy_score(y_train,y_pred))
        y_pred=model.predict(x_test)
        print(i, ' out-of-sample accuracy in SVM: ', accuracy_score(y_test,y_pred))
        rate.append(accuracy_score(y_test,y_pred))
    nloc = rate.index(max(rate))
    print("Highest accuracy is %s occurs at %s kernel." % (rate[nloc], kernel[nloc]))
    return kernel[nloc]

# %%
def svm_error (k ,C , x_train , y_train , x_test , y_test ) :
    error_rate = []
    C = range (1 , C)
    for i in C :
        model = svm . SVC ( kernel =k , C = i ) . fit ( x_train , y_train )
        model . fit ( x_train , y_train )

        y_pred = model . predict ( x_test )
        error_rate . append ( np . mean ( y_pred != y_test ) )
    cloc = error_rate.index(min( error_rate ) )
    print (" Lowest error is %s occurs at C=%s." % ( error_rate [ cloc ] , C [cloc]) )
    return error_rate[cloc]

# %%
k=svm_kernel(x_train,y_train,x_test,y_test)
# Out:
# rbf  in-sample accuracy in SVM:  0.9802683504340963
# rbf  out-of-sample accuracy in SVM:  0.9794952681388013
# poly  in-sample accuracy in SVM:  0.9822415153906867
# poly  out-of-sample accuracy in SVM:  0.9794952681388013
# linear  in-sample accuracy in SVM:  0.9763220205209155
# linear  out-of-sample accuracy in SVM:  0.9716088328075709
# Highest accuracy is 0.9794952681388013 occurs at rbf kernel.

# %%
c=svm_error(k,10,x_train,y_train,x_test,y_test)
# Out:
#  Lowest error is 0.01892744479495268 occurs at C=2.

# %%
model=svm.SVC(kernel=k,C=c)
t = classify(model,x_train,y_train,x_test,y_test)
accli.at['Support Vector Machine', 'Accuracy (considering all attributes)'] = t
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9798    0.7864    0.8725       309
#         male     0.8290    0.9846    0.9001       325
#
#     accuracy                         0.8880       634
#    macro avg     0.9044    0.8855    0.8863       634
# weighted avg     0.9025    0.8880    0.8867       634
#
# Accuracy: 0.88801261829653

# %%
k=svm_kernel(x_train3,y_train3,x_test3,y_test3)
# Out:
# rbf  in-sample accuracy in SVM:  0.9727703235990529
# rbf  out-of-sample accuracy in SVM:  0.9716088328075709
# poly  in-sample accuracy in SVM:  0.9700078926598263
# poly  out-of-sample accuracy in SVM:  0.9700315457413249
# linear  in-sample accuracy in SVM:  0.9672454617205999
# linear  out-of-sample accuracy in SVM:  0.9621451104100947
# Highest accuracy is 0.9716088328075709 occurs at rbf kernel.

# %%
c=svm_error(k,10,x_train3,y_train3,x_test3,y_test3)
# Out:
#  Lowest error is 0.02050473186119874 occurs at C=4.

# %%
model=svm.SVC(kernel=k,C=c)
t = classify(model,x_train3,y_train3,x_test3,y_test3)
accli.at['Support Vector Machine', 'Accuracy (considering only IQR, meanfun & Q25)'] = t
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9731    0.9353    0.9538       309
#         male     0.9407    0.9754    0.9577       325
#
#     accuracy                         0.9558       634
#    macro avg     0.9569    0.9553    0.9557       634
# weighted avg     0.9564    0.9558    0.9558       634
#
# Accuracy: 0.9558359621451105
